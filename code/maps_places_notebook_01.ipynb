# %%
pip install googlemaps
# Out:
#   File "<ipython-input-3-fe3427f9d6f7>", line 1
#     pip install googlemaps
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import googlemaps
import pandas as pd

# %%
# API Key
gmaps = googlemaps.Client(key='AIzaSyA34t4OLue4SRaxHQ0SNhoJ-Sfvuvnnblo')

# %%
# Get Places ID
place_name = 'Sbahn Station Mühlberg'

places_result = gmaps.places(place_name)
place_id = places_result['results'][0]['place_id']
place_id
# Out:
# 'ChIJv3vq5iYMvUcR-x1-1Vp-kRs'

# %%
# Get Review
place = gmaps.place(place_id = place_id)

reviews = [] #empty list which will hold dictionaries of reviews

for i in range(len(place['result']['reviews'])):
    text = place['result']['reviews'][i]['text']
    rating = place['result']['reviews'][i]['rating']

    reviews.append({'rating':rating,
                   'text':text
                   }
                  )

df = pd.DataFrame(reviews)
df
# Out:
#    rating                                               text
# 0       5  My first time to coming into this station.\nIt...
# 1       2  Scoreboards were replaced many months ago, but...
# 2       4  I can't find much fault with this stop. It is ...
# 3       1  New scoreboards installed some time ago but on...
# 4       1  Bottom drawer elevator forever out of order!!!...
