# %% [markdown]
# <a href="https://colab.research.google.com/github/merliou/term_paper_css/blob/main/bert_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installiere die notwendigen Bibliotheken
# !pip install bertopic
# !pip install umap-learn
# !pip install pandas
# !pip install numpy

# Importiere die notwendigen Bibliotheken
import pandas as pd
import numpy as np
from bertopic import BERTopic
from umap import UMAP
#from hdbscan import HDBSCAN

# Lade die CSV-Datei
data = pd.read_csv("10_data_covs_avg_no_doubles.csv", header=0)

## draw 10 percent random sample
#np.random.seed(161)
#data = data.sample(frac=0.1)

data['ort'] = data['ort']
data['bundesland'] = data['bundesland']
data['rating_rez'] = data['bewertung']
data['rezension'] = data['rezension']
data['traeger'] = data['Traeger']
data['typ'] = data['EinrichtungsTyp']
data['versorgungsstufe'] = data['Allgemeine_Notfallversorgung']
data['bettenzahl'] = data['INSG']
data['rating_avg'] = data['rating']
data['number_of_ratings'] = data['total_ratings']

data['bundesland'].value_counts()
data['rating_rez'].value_counts()
data['traeger'].value_counts()
data['typ'].value_counts()
data['versorgungsstufe'].value_counts()
data['rating_avg'].value_counts()


# Zeige die ersten 3 Zeilen der Daten an
print(data.iloc[0:3])

## Bereite die Daten vor (falls nötig)
## In diesem Fall verwenden wir die Spalte 'rezension' für die Textanalyse
#documents = data['rezension'].tolist()
#
## Erstelle das UMAP-Modell
#umap_model = UMAP(random_state=1337)
#
## Erstelle das BERTopic-Modell
#topic_model = BERTopic(umap_model=umap_model)
#
## Führe das Modell auf den Dokumenten aus
#topics, probs = topic_model.fit_transform(documents)
#
## Zeige die häufigsten Themen an
#topic_info = topic_model.get_topic_info()
#print(topic_info)
# Out:
# bundesland
# 5.0     2347
# 9.0     2065
# 8.0     1432
# 3.0     1002
# 6.0      994
# 7.0      582
# 1.0      570
# 11.0     493
# 14.0     458
# 12.0     422
# 16.0     355
# 2.0      318
# 15.0     311
# 13.0     249
# 10.0     114
# 4.0       70
# Name: count, dtype: int64

# %% [markdown]
# Data cleaning

# %%
# Überprüfe auf fehlende Werte in der Spalte 'rezension'
print(data['rezension'].isnull().sum())

# Entferne Zeilen mit fehlenden Werten
data = data.dropna(subset=['rezension'])

## Oder ersetze fehlende Werte durch einen leeren String
#data['rezension'] = data['rezension'].fillna("")

# Extrahiere die Dokumente
documents = data['rezension'].tolist()

# Überprüfe die ersten 5 Dokumente
print(documents[:5])

# Überprüfe den Datentyp der Spalte 'rezension'
print(data['rezension'].dtype)

data['rezension'] = data['rezension'].astype(str)

# %% [markdown]
# Modell ausführen

# %%
## Extrahiere die Dokumente
#documents = data['rezension'].tolist()

# Erstelle das BERTopic-Modell
topic_model = BERTopic(min_topic_size=9) # Minimalanzahl an Topics einstellen

# Führe das Modell auf den Dokumenten aus
topics, probs = topic_model.fit_transform(documents)

# Zeige die Themeninformationen an
topic_info = topic_model.get_topic_info()
print(topic_info)
# Out:
#     Topic  Count                                 Name  \
# 0      -1   6319                   -1_und_ich_die_der
# 1       0    648                  0_klinik_die_und_in
# 2       1    397                    1_die_und_der_ich
# 3       2    394            2_krankenhaus_das_und_ist
# 4       3    337           3_krankenhaus_ich_nicht_in
# ..    ...    ...                                  ...
# 76     75     10  75_notaufnahme_in_freitagabend_eine
# 77     76     10            76_geholfen_mir_bar_super
# 78     77     10           77_zimmer_wurde_fehler_ich
# 79     78      9    78_personal_alternativen_ist_oder
# 80     79      9   79_mhh_ihrem_patienten_krankenhaus
#
#                                        Representation  \
# 0   [und, ich, die, der, das, war, sehr, in, nicht...
# 1   [klinik, die, und, in, der, ich, ist, zu, das,...
# 2   [die, und, der, ich, nicht, zu, in, mit, dass,...
# 3   [krankenhaus, das, und, ist, sehr, ich, ein, d...
# 4   [krankenhaus, ich, nicht, in, das, sie, und, d...
# ..                                                ...
# 76  [notaufnahme, in, freitagabend, eine, behandlu...
# 77  [geholfen, mir, bar, super, dickes, weiterempf...
# 78  [zimmer, wurde, fehler, ich, am, mose, schmidt...
# 79  [personal, alternativen, ist, oder, unfreundli...
# 80  [mhh, ihrem, patienten, krankenhaus, die, fr, ...
#
#                                   Representative_Docs
# 0   [Sehr gute Fachklinik alles in allem. Als ambu...
# 1   [Ich bin gerade hier in dieser Klinik und kann...
# 2   [Ich habe noch nie etwas so unmenschliches mit...
# 3   [Ich war jetzt nur als Besucher dort. War aber...
# 4   [Mit diesen Worten begrüßt das Krankenhaus auf...
# ..                                                ...
# 76  [Nie wieder!\n\nDie Erfahrung in der Notaufnah...
# 77  [Es wurde mir dort kompetent geholfen. Das gan...
# 78  [Meine Tochter 14 Jahre alt, wurde von der Par...
# 79  [Ich muss hier eine Lanze für die PIA brechen,...
# 80  [ich möchte Ihnen ein herzliches Feedback gebe...
#
# [81 rows x 5 columns]

# %% [markdown]
# Modell 2: Dok's in einzelne Sätze gesplittet

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

def split_into_sentences(text):
  sentences = nltk.sent_tokenize(text, language='german') # use language='german' for German text.
  return sentences

# Wende die Funktion auf alle Rezensionen an
split_documents = [split_into_sentences(doc) for doc in documents]
# flatten the list for Bertopic
all_sentences = [sentence for sublist in split_documents for sentence in sublist]

# Erstelle und trainiere das BERTopic-Modell mit den Sätzen
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(all_sentences)

# %%
# Zeige die Dokumentinformationen an
document_info = topic_model.get_document_info(documents)
print(document_info)

# Visualisiere die Ergebnisse
# Themen-Distanz
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="854ebdbd-d9a1-4875-8052-d2a6abc50f92" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("854ebdbd-d9a1-4875-8052-d2a6abc50f92")) {                    Plotly.newPlot(                        "854ebdbd-d9a1-4875-8052-d2a6abc50f92",                        [{"customdata":[[0,"klinik | die | und | in | der",648],[1,"die | und | der | ich | nicht",397],[2,"krankenhaus | das | und | ist | sehr",394],[3,"krankenhaus | ich | nicht | in | das",337],[4,"klinik | die | in | sehr | und",307],[5,"station | auf | sehr | war | gut",259],[6,"tagesklinik | sehr | und | die | mich",205],[7,"station | auf | und | ich | die",203],[8,"sehr | gut | fhle | aufgehoben | dort",162],[9,"tagesklinik | die | tag | ich | und",139],[10,"sie | schmerzen | ich | dann | nicht",115],[11,"patienten | patient | als | man | sehr",114],[12,"team | gesamte | dank | an | vielen",108],[13,"pflegepersonal | rzte | sehr | freundlich | und",98],[14,"essen | das | es | war | die",83],[15,"personal | sehr | freundlich | das | hat",79],[16,"alles | alle | sehr | und | wir",74],[17,"tolle | tolles | toll | team | tollen",67],[18,"telefon | telefonisch | man | ans | telefonische",64],[19,"termin | einen | dann | ich | termine",62],[20,"behandlung | behandelt | ohne | sehr | und",60],[21,"essen | gut | sehr | sind | ist",57],[22,"termin | einen | man | warten | dran",56],[23,"notaufnahme | in | uhr | warten | war",50],[24,"gewesen | sehr | bin | zufrieden | freundlich",48],[25,"parkplatz | parkpltze | parken | ist | einen",46],[26,"psychologen | geholfen | nicht | man | wird",45],[27,"personal | patienten | ist | sehr | in",41],[28,"mann | mein | er | hat | und",40],[29,"pflegepersonal | station | rzte | gut | sehr",40],[30,"pflegepersonal | krankenhaus | station | und | dieses",40],[31,"ich | mich | dass | und | mir",38],[32,"uns | wir | eltern | geburt | hebammen",37],[33,"personal | klinik | ist | freundlich | sehr",33],[34,"2024 | 2025 | 2023 | sehr | station",33],[35,"augen | auge | augenklinik | lasern | lassen",30],[36,"hygiene | man | patienten | zimmer | wird",28],[37,"personal | krankenhaus | sehr | freundlich | diesem",28],[38,"orthopdie | euro | dr | bei | min",27],[39,"top | sehr | immer | personal | adresse",27],[40,"krankenhaus | patienten | dieses | ist | das",25],[41,"gut | gute | war | essen | sehr",23],[42,"depressionen | depression | wegen | meiner | schweren",22],[43,"2024 | september | sehr | personal | november",21],[44,"stern | sterne | vergeben | geben | zuviel",21],[45,"trauma | traumatisiert | traumatologie | traumata | du",20],[46,"notfallambulanz | notfall | nach | unfall | notflle",19],[47,"praxis | praxisteam | erklrt | frau | dr",19],[48,"empfang | empfehlen | empfangen | gab | unangenehmes",19],[49,"super | supernett | team | nettes | nett",18],[50,"cafeteria | kiosk | ok | personal | keller",18],[51,"schmerzen | nehmen | schmerzmittel | starken | man",17],[52,"geld | gelnde | hier | mitarbeiter | bezahlen",16],[53,"sohn | unserem | unser | schnell | wir",16],[54,"min | minuten | 10 | 15 | nach",16],[55,"katastrophe | reinste | absolute | stern | unterlassene",15],[56,"klinik | mich | diese | die | pittlik",15],[57,"klinik | station | empfehlen | sehr | und",15],[58,"klinik | station | hallux | op | valgus",15],[59,"schlaflabor | schlafabnoe | liebsten | sehr | berhaupt",15],[60,"station | sehr | bernburg | dank | versorgung",14],[61,"the | and | notaufnahme | er | nach",14],[62,"team | an | teams | und | patienten",13],[63,"rztin | arzt | vorsorge | mainz | hren",13],[64,"uhr | sie | um | warten | in",13],[65,"moegelin | alles | sehr | gut | habe",13],[66,"schwestern | nette | rzte | sehr | nettsehr",12],[67,"laden | letzte | abgewimmelt  ...

# %%
# Wort-Scores
topic_model.visualize_barchart() # erste 10 topics
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a901fc28-65e9-405a-9107-a31690167e39" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a901fc28-65e9-405a-9107-a31690167e39")) {                    Plotly.newPlot(                        "a901fc28-65e9-405a-9107-a31690167e39",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.010327500479123314,0.010370870063842812,0.010801881989628451,0.011540710906052458,0.016885558127512197],"y":["der  ","in  ","und  ","die  ","klinik  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.009136292233215028,0.009665740001793618,0.00968942683231465,0.010116497153556968,0.010687827823170588],"y":["nicht  ","ich  ","der  ","und  ","die  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010711494835647399,0.010776461766535505,0.010986614743017679,0.01154994462289173,0.03810540070861405],"y":["sehr  ","ist  ","und  ","das  ","krankenhaus  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.009464749912170422,0.009539087835907893,0.009617714900988856,0.009992171587054649,0.019604047404136533],"y":["das  ","in  ","nicht  ","ich  ","krankenhaus  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.012062738683160166,0.013082606864487149,0.013113126078010231,0.013572195323808236,0.03524225988423935],"y":["und  ","sehr  ","in  ","die  ","klinik  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01356462937549161,0.014181926079309907,0.015371271338047951,0.017827570185255163,0.03672834100116047],"y":["gut  ","war  ","sehr  ","auf  ","station  "],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histo ...

# %%
# Themen-Similarität
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d88a6f1b-eb20-4bb3-a2e9-84825339697a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d88a6f1b-eb20-4bb3-a2e9-84825339697a")) {                    Plotly.newPlot(                        "d88a6f1b-eb20-4bb3-a2e9-84825339697a",                        [{"coloraxis":"coloraxis","name":"0","x":["0_klinik_die_und","1_die_und_der","2_krankenhaus_das_und","3_krankenhaus_ich_nicht","4_klinik_die_in","5_station_auf_sehr","6_tagesklinik_sehr_und","7_station_auf_und","8_sehr_gut_fhle","9_tagesklinik_die_tag","10_sie_schmerzen_ich","11_patienten_patient_als","12_team_gesamte_dank","13_pflegepersonal_rzte_sehr","14_essen_das_es","15_personal_sehr_freundlich","16_alles_alle_sehr","17_tolle_tolles_toll","18_telefon_telefonisch_man","19_termin_einen_dann","20_behandlung_behandelt_ohne","21_essen_gut_sehr","22_termin_einen_man","23_notaufnahme_in_uhr","24_gewesen_sehr_bin","25_parkplatz_parkpltze_parken","26_psychologen_geholfen_nicht","27_personal_patienten_ist","28_mann_mein_er","29_pflegepersonal_station_r...","30_pflegepersonal_krankenha...","31_ich_mich_dass","32_uns_wir_eltern","33_personal_klinik_ist","34_2024_2025_2023","35_augen_auge_augenklinik","36_hygiene_man_patienten","37_personal_krankenhaus_sehr","38_orthopdie_euro_dr","39_top_sehr_immer","40_krankenhaus_patienten_di...","41_gut_gute_war","42_depressionen_depression_...","43_2024_september_sehr","44_stern_sterne_vergeben","45_trauma_traumatisiert_tra...","46_notfallambulanz_notfall_...","47_praxis_praxisteam_erklrt","48_empfang_empfehlen_empfan...","49_super_supernett_team","50_cafeteria_kiosk_ok","51_schmerzen_nehmen_schmerz...","52_geld_gelnde_hier","53_sohn_unserem_unser","54_min_minuten_10","55_katastrophe_reinste_abso...","56_klinik_mich_diese","57_klinik_station_empfehlen","58_klinik_station_hallux","59_schlaflabor_schlafabnoe_...","60_station_sehr_bernburg","61_the_and_notaufnahme","62_team_an_teams","63_rztin_arzt_vorsorge","64_uhr_sie_um","65_moegelin_alles_sehr","66_schwestern_nette_rzte","67_laden_letzte_abgewimmelt","68_asthma_danke_lungenarzt","69_station_klinik_31","70_essen_personal_fhlte","71_essen_alpspitz_wochen","72_leider_faden_beim","73_schwiegermutter_schutzkl...","74_diabetes_diabetikerin_sehr","75_notaufnahme_in_freitagab...","76_geholfen_mir_bar","77_zimmer_wurde_fehler","78_personal_alternativen_ist","79_mhh_ihrem_patienten"],"y":["0_klinik_die_und","1_die_und_der","2_krankenhaus_das_und","3_krankenhaus_ich_nicht","4_klinik_die_in","5_station_auf_sehr","6_tagesklinik_sehr_und","7_station_auf_und","8_sehr_gut_fhle","9_tagesklinik_die_tag","10_sie_schmerzen_ich","11_patienten_patient_als","12_team_gesamte_dank","13_pflegepersonal_rzte_sehr","14_essen_das_es","15_personal_sehr_freundlich","16_alles_alle_sehr","17_tolle_tolles_toll","18_telefon_telefonisch_man","19_termin_einen_dann","20_behandlung_behandelt_ohne","21_essen_gut_sehr","22_termin_einen_man","23_notaufnahme_in_uhr","24_gewesen_sehr_bin","25_parkplatz_parkpltze_parken","26_psychologen_geholfen_nicht","27_personal_patienten_ist","28_mann_mein_er","29_pflegepersonal_station_r...","30_pflegepersonal_krankenha...","31_ich_mich_dass","32_uns_wir_eltern","33_personal_klinik_ist","34_2024_2025_2023","35_augen_auge_augenklinik","36_hygiene_man_patienten","37_personal_krankenhaus_sehr","38_orthopdie_euro_dr","39_top_sehr_immer","40_krankenhaus_patienten_di...","41_gut_gute_war","42_depressionen_depression_...","43_2024_september_sehr","44_stern_sterne_vergeben","45_trauma_traumatisiert_tra...","46_notfallambulanz_notfall_...","47_praxis_praxisteam_erklrt","48_empfang_empfehlen_empfan...","49_super_supernett_team","50_cafeteria_kiosk_ok","51_schmerzen_nehmen_schmerz...","52_geld_gelnde_hier","53 ...

# %%
# Themen-Hierarchie
topic_model.visualize_hierarchy()

pip install -U kaleido
import kaleido
topic_model.visualize_hierarchy().write_image("hierarchical_clustering.png") # als Bild speichern
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-bf2d4f6588c5> in <cell line: 0>()
# ----> 1 topic_model.visualize_hierarchy().write_image("hierarchical_clustering.png") # als Bild speichern
#
# /usr/local/lib/python3.11/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3833         import plotly.io as pio
#    3834
# -> 3835         return pio.write_image(self, *args, **kwargs)
#    3836
#    3837     # Static helpers
#
# /usr/local/lib/python3.11/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#
# /usr/local/lib/python3.11/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     130     # Raise informative error message if Kaleido is not installed
#     131     if scope is None:
# --> 132         raise ValueError(
#     133             """
#     134 Image export using the "kaleido" engine requires the kaleido package,
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %%
# Zeige spezifische Themen an (z.B. Thema 49)
specific_topic = topic_model.get_topic(49)
print(specific_topic)

# Zeige repräsentative Dokumente für spezifische Themen an (z.B. Thema 49 und 82)
representative_docs_49 = topic_model.get_representative_docs(topic=49)
representative_docs_82 = topic_model.get_representative_docs(topic=82)
print(representative_docs_49)
print(representative_docs_82)
# Out:
# [('station', np.float64(0.03075882698078743)), ('klinik', np.float64(0.027546367922963364)), ('bis', np.float64(0.0220624117142804)), ('31', np.float64(0.019609307870642197)), ('sehr', np.float64(0.019021210113480475)), ('vom', np.float64(0.017089858739553477)), ('mich', np.float64(0.015538967779543769)), ('an', np.float64(0.015220149515462798)), ('stationr', np.float64(0.014620596392466096)), ('ihr', np.float64(0.013943521142597984))]
# ['Eine sehr gute Klinik. Ich war 1 Woche stationär auf St. 31 und wurde sehr gut betreut. Ein großes Lob und Dankeschön an Dr. M. Stockbauer und OÄ Dr. Wallisch für die hervorragende Behandlung.\nAlle Mitarbeiter/innen auf St. 31 geben ihr bestes und waren überaus freundlich und bemüht.\nDer einzigste Minuspunkt ist das Essen, leider nicht sehr gut, aber auch das überlebt man :-)\nViele Grüße,  Claudia Grimm', 'Ich war vor einer Woche in der Klinik. Angefangen bei der Patientenaufnahme über das OP-Team bis zur Station sehr freundliche und hilfsbereite Menschen (immer ein offenes Ohr für Fragen und Ängste). Großes Lob an die Station M2. Sehr aufmerksame und liebevolle Pflege. Ich fühlte mich in guten Händen. Herzlichen Dank.\nMonika Ebenhöch', 'Ich war vom22.04 bis 10.05.2024 auf der MMS Station.\nSehr kompetente, freundliche Ärzte, Schwestern und Pfleger immer ein offenes Ohr für jeden Patienten, sehr gute Organisation in allen Bereichen.\nDas Essen hätte für eine Klinik nicht besser sein können. Ich habe mich sehr gut aufgehoben gefühlt.\nIhr seid ein tolles Team macht weiter so.\nVielen lieben Dank für alles\nLiebe Grüße Alfons Damm']
# None

# %% [markdown]
# Fine tuning

# %%
# Benutzerdefinierte Themen-Labels setzen
topic_model.set_topic_labels({49: "Krankenhaus Erfahrungen", 82: "Psychiatrische Behandlung"})
print(topic_model.get_topic_info(49))
print(topic_model.get_topic_info(82))

# Themen pro Klasse (falls eine Klassenspalte vorhanden ist)
classes = data['versorgungsstufe'] # bei versorgungsstufe gibts Probleme

topics_per_class = topic_model.topics_per_class(documents, classes=classes)
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=31)

# Ändere das Clustering-Modell zu KMeans
from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=30)  # Verwende KMeans-Clustering mit ... Themen
topic_model_kmeans = BERTopic(hdbscan_model=cluster_model)
topicsKmeans, probsKmeans = topic_model_kmeans.fit_transform(documents)

# Zeige die Themeninformationen für das KMeans-Modell an
topic_info_kmeans = topic_model_kmeans.get_topic_info()
print(topic_info_kmeans)

# Output in Tabellenform
html_table = topic_info.to_html()
with open("topic_info.html", "w", encoding='utf-8') as f:
    f.write(html_table)

# Zeige die Dokumentinformationen für das KMeans-Modell an
document_info_kmeans = topic_model_kmeans.get_document_info(documents)
print(document_info_kmeans)

## Geführte Themenmodelle (Guided Topic Models)
#seed_topic_list = [["warte"],
#                   ["schmerz"],
#                   ["frechheit"],
#                   ["freundlich"]]

topic_model_guided = BERTopic(seed_topic_list=seed_topic_list)
topics_guided, probs_guided = topic_model_guided.fit_transform(documents)

# Zeige die Themeninformationen für das geführte Modell an
topic_info_guided = topic_model_guided.get_topic_info()
print(topic_info_guided)

# Visualisiere die Ergebnisse des geführten Modells
topic_model_guided.visualize_barchart(n_words=8, top_n_topics=12)

# Zeige die Dokumentinformationen für das geführte Modell an
document_info_guided = topic_model_guided.get_document_info(documents)
print(document_info_guided)
