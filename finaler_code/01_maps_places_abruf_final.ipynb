# %% [markdown]
# Vorbereitung

# %%
# !pip install googlemaps
# !pip install pandas
# !pip install openpyxl

import googlemaps
import pandas as pd
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.1.31)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40715 sha256=3cc7f47c07870aad2e7b2479b5ebe385e3c1ed63f727c146edd5142d2098a420
#   Stored in directory: /root/.cache/pip/wheels/f1/09/77/3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %% [markdown]
# TESTUMGEBUNG

# %%
# Lade die TEST CSV-Datei
# df = pd.read_csv(r'/content/test_verzeichnis.csv', encoding='latin1')

# %% [markdown]
# AB HIER ERNSTHAFT: Liste der Orte laden

# %%
# Daten Krankenhausverzeichnis 2023 laden
df_khv = pd.read_excel(r'/content/2023_krankenhausverzeichnis.xlsx', sheet_name="KHV_2023", header=2)

# Kontrolle
print(df_khv.head())
print(df_khv.info())
print(df_khv.shape)

# Neuer df nur mit den nötigsten Werten
gewuenschte_spalten = ['Land', 'Adresse_Name', 'Adresse_Name_Standort', 'Adresse_Strasse_Standort', 'Adresse_Haus-Nr._Standort', 'Adresse_Postleitzahl_Standort', 'Adresse_Ort_Standort', 'Traeger', 'T_Name', 'EinrichtungsTyp', 'Allgemeine_Notfallversorgung', 'INSG']

# Auf das Wesentliche reduzierter DF:
df_red = pd.DataFrame()

# Spalten aus dem alten DataFrame in den neuen DataFrame kopieren
for spalte in gewuenschte_spalten:
    df_red[spalte] = df_khv[spalte]

# Kontrolle des neuen DataFrames
print(df_red.head())
print(df_red.info())
print(df_red.shape)

# Subdataframes, für übersichtlicheres Abrufen
df_red_1 = df_red.iloc[0:700]
df_red_2 = df_red.iloc[700:1400]
df_red_3 = df_red.iloc[1400:2100]
df_red_4 = df_red.iloc[2100:]

# Leere Liste, um die Ergebnisse zu speichern
# ergebnisse = []
# Out:
#    Land  Kreis  Gemeinde                                       Adresse_Name  \
# 0   1.0    1.0       0.0                            DIAKO Krankenhaus gGmbH
# 1   1.0    1.0       0.0  DIAKO Nordfriesland gGmbH - DIAKO Fachklinik f...
# 2   1.0    1.0       0.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
# 3   1.0    1.0       0.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
# 4   1.0    1.0       0.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
#
#                                Adresse_Name_Standort Adresse_Strasse_Standort  \
# 0                            DIAKO Krankenhaus gGmbH              Knuthstraße
# 1  DIAKO Fachklinik für Psychiatrie, Psychosomati...              Knuthstraße
# 2             DIAKO Tagesklinik für Ältere Flensburg        Marienhölzungsweg
# 3         DIAKO Tagesklinik für Erwachsene Flensburg        Marienhölzungsweg
# 4          DIAKO Tagesklinik für KJP (Villa Paletti)        Marienhölzungsweg
#
#   Adresse_Haus-Nr._Standort  Adresse_Postleitzahl_Standort  \
# 0                         1                        24939.0
# 1                         1                        24939.0
# 2                         8                        24939.0
# 3                        21                        24939.0
# 4                        68                        24939.0
#
#   Adresse_Ort_Standort Telefonvorwahl -nummer  ... 3750 3751  3752 3753  3754  \
# 0            Flensburg             0461 812-0  ...  NaN  NaN   NaN  NaN   NaN
# 1            Flensburg          0461 812-1701  ...  NaN  NaN   NaN  NaN   NaN
# 2            Flensburg            04671 408-0  ...  NaN  NaN   NaN  NaN   NaN
# 3            Flensburg            04671 408-0  ...  NaN  NaN   NaN  NaN   NaN
# 4            Flensburg            04671 408-0  ...  NaN  NaN   NaN  NaN   NaN
#
#    3755  3756  3757  3758  3759
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 172 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2783 entries, 0 to 2782
# Columns: 172 entries, Land to 3759
# dtypes: float64(163), object(9)
# memory usage: 3.7+ MB
# None
# (2783, 172)
#    Land                                       Adresse_Name  \
# 0   1.0                            DIAKO Krankenhaus gGmbH
# 1   1.0  DIAKO Nordfriesland gGmbH - DIAKO Fachklinik f...
# 2   1.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
# 3   1.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
# 4   1.0  DIAKO Nordfriesland gGmbH - DIAKO Tagesklinike...
#
#                                Adresse_Name_Standort Adresse_Strasse_Standort  \
# 0                            DIAKO Krankenhaus gGmbH              Knuthstraße
# 1  DIAKO Fachklinik für Psychiatrie, Psychosomati...              Knuthstraße
# 2             DIAKO Tagesklinik für Ältere Flensburg        Marienhölzungsweg
# 3         DIAKO Tagesklinik für Erwachsene Flensburg        Marienhölzungsweg
# 4          DIAKO Tagesklinik für KJP (Villa Paletti)        Marienhölzungsweg
#
#   Adresse_Haus-Nr._Standort  Adresse_Postleitzahl_Standort  \
# 0                         1                        24939.0
# 1                         1                        24939.0
# 2                         8                        24939.0
# 3                        21                        24939.0
# 4                        68                        24939.0
#
#   Adresse_Ort_Standort  Traeger                     T_Name  EinrichtungsTyp  \
# 0            Flensburg      2.0    DIAKO Krankenhaus gGmbH              2.0
# 1            Flensburg      2.0  DIAKO Nordfriesland gGmbH              2.0
# 2            Flensburg      2.0  DIAKO Nordfriesland gGmbH              2.0
# 3            Flensburg      2.0  DIAKO Nordfriesland gGmbH              2.0
# 4            Flensburg      2.0  DIAKO Nordfriesland gGmbH              2.0
#
#    Allgemeine_Notfallversorgung   INSG
# 0                           2.0  400.0
# 1                           0.0   87.0
# 2                           0.0    0.0
# 3                           0.0    0.0
# 4                           0.0    0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2783 entries, 0 to 2782
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Land                           2781 non-null   float64
#  1   Adresse_Name                   2781 non-null   object
#  2   Adresse_Name_Standort          2780 non-null   object
#  3   Adresse_Strasse_Standort       2781 non-null   object
#  4   Adresse_Haus-Nr._Standort      2758 non-null   object
#  5   Adresse_Postleitzahl_Standort  2781 non-null   float64
#  6   Adresse_Ort_Standort           2781 non-null   object
#  7   Traeger                        2781 non-null   float64
#  8   T_Name                         2781 non-null   object
#  9   EinrichtungsTyp                2781 non-null   float64
#  10  Allgemeine_Notfallversorgung   2759 non-null   float64
#  11  INSG                           2782 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 261.0+ KB
# None
# (2783, 12)

# %% [markdown]
# Maps API Abruf

# %%
# Google Maps Client initialisieren
gmaps = googlemaps.Client(key='API')

# ------- TODOS: -----------------
# Fortlaufenden Versonsnamen hier manuell eintragen: !!
list_name_dict = {}
list_name = "4_3_ergebnisse" #hier!
list_name_dict[list_name] = []  # leere liste für ergebnissen
df_name = f"{list_name}_df"
list_name_dict[df_name] = None
csv_name = f"{list_name}.csv" # output datei

# Abzurufendes KHV-Subset definieren !!
subset_name_dict = {}
subset_name = "df_red_3" #hier!
subset_name_dict[subset_name] = df_red_3 #hier!
df_red_version = subset_name_dict[subset_name]

# --------------------------------

# Durch Orte iterieren
for index, row in df_red_version.iterrows():
#    if index >= 10:
#        break

    name = row['Adresse_Name']
    strasze = row['Adresse_Strasse_Standort']
    hausnr = row['Adresse_Haus-Nr._Standort']
    stadt = row['Adresse_Ort_Standort']
    bundesland = row['Land']
    ort = f"{name}, {strasze} {hausnr}, {stadt}"
    try:
        # Suche nach Orten
        places_result = gmaps.places(ort)

        if places_result and places_result['results']:
            place_id = places_result['results'][0]['place_id']
            place = gmaps.place(place_id=place_id, language='de')

            rezensionen_zaehler = 0
            for review in place['result']['reviews']:

                list_name_dict[list_name].append({  # Füge der Liste im Dictionary hinzu
                    'ort': ort,
                    'name': name,
                    'strasze': strasze,
                    'hausnr': hausnr,
                    'stadt': stadt,
                    'bundesland': bundesland,
                    'place_id': place_id,
                    'bewertung': review['rating'],
                    'rezension': review['text'],
                    'zeit': review['relative_time_description']
                })
                rezensionen_zaehler += 1
                if rezensionen_zaehler >= 5:
                    break
        else:
            print(f"Keine Ergebnisse gefunden für {ort}")
    except Exception as e:
        print(f"Fehler bei der Verarbeitung von {ort}: {e}")

# DataFrame erstellen
list_name_dict[df_name] = pd.DataFrame(list_name_dict[list_name])  # Erstelle DataFrame aus der Liste

# Speichern
list_name_dict[df_name].to_csv(csv_name, index=False, encoding='utf-8-sig')
# Out:
# Fehler bei der Verarbeitung von ViaNobis - Die Fachklinik, Genneper Straße 2, Heinsberg, Rheinland: 'reviews'
# Keine Ergebnisse gefunden für LWL-Universitätsklinik Hamm der Ruhr-Universität Bochum, Im Füchtei 148, Gütersloh
# Keine Ergebnisse gefunden für Klinikum Westfalen GmbH - KKDO, KaP, HK, Brechtener Straße 59, Lünen
# Fehler bei der Verarbeitung von Vitos Rheingau gGmbH, Auf der Wahnsbach 6, Katzenelnbogen: 'reviews'
# Fehler bei der Verarbeitung von Kliniken des Main-Taunus-Kreises GmbH, Nassauer Straße 4, Hattersheim: 'reviews'
# Fehler bei der Verarbeitung von Rheinhessen-Fachklinik, Hartmühlenweg 2-4, Mainz am Rhein: 'reviews'
# Fehler bei der Verarbeitung von MEDIAN Klinik Sonnenwende Bad Dürkheim, Östlicher Graben 25, Grünstadt: 'reviews'

# %% [markdown]
# Durchschnittliche Bewertung ebenfalls abrufen

# %%
# Schritt 1: Liste mit eindeutigen place_ids erstellen
def get_unique_place_ids(csv_file: str) -> List[str]:
    """Liest die CSV-Datei und gibt eine Liste mit eindeutigen place_ids zurück."""
    df = pd.read_csv(csv_file)
    unique_place_ids = df['place_id'].unique().tolist()
    return unique_place_ids

# Schritt 2: Liste in vier Teile splitten
def split_list(lst: List[Any], parts: int = 4) -> List[List[Any]]:
    """Teilt eine Liste in annähernd gleich große Teile auf."""
    return [lst[i::parts] for i in range(parts)]

# Schritt 3: Bewertungen über die Google Maps Places API abrufen
def get_place_ratings(api_key: str, place_ids: List[str]) -> Dict[str, float]:
    """
    Ruft die Bewertungen für eine Liste von place_ids ab.

    Args:
        api_key: Ihr Google Maps API-Schlüssel
        place_ids: Liste von place_ids

    Returns:
        Dictionary mit place_id als Schlüssel und Bewertung als Wert
    """
    base_url = "https://maps.googleapis.com/maps/api/place/details/json"
    ratings = {}

    for place_id in place_ids:
        params = {
            'place_id': place_id,
            'fields': 'rating',
            'key': api_key
        }

        try:
            response = requests.get(base_url, params=params)
            data = response.json()

            if data['status'] == 'OK':
                rating = data['result'].get('rating', None)
                ratings[place_id] = rating
            else:
                print(f"Fehler für place_id {place_id}: {data['status']}")
                ratings[place_id] = None

            # Pause einlegen, um API-Rate-Limits nicht zu überschreiten
            time.sleep(1)  # 1 Anfrage pro Sekunde ist sicher

        except Exception as e:
            print(f"Fehler beim Abrufen der Daten für {place_id}: {str(e)}")
            ratings[place_id] = None

    return ratings

def main():
    # Ihre Google Maps API Key
    API_KEY = "AIzaSyA34t4OLue4SRaxHQ0SNhoJ-Sfvuvnnblo"

    # CSV-Datei einlesen
    csv_file = "/content/08_data_and_covariates.csv"

    # Schritt 1: Eindeutige place_ids erhalten
    unique_place_ids = get_unique_place_ids(csv_file)
    print(f"Anzahl eindeutiger place_ids: {len(unique_place_ids)}")

    # Schritt 2: Liste in 4 Teile splitten
    split_place_ids = split_list(unique_place_ids, parts=4)
    for i, part in enumerate(split_place_ids, 1):
        print(f"Teil {i}: {len(part)} place_ids")

    # Schritt 3: Bewertungen abrufen (Beispiel für einen Teil)
    # Wählen Sie einen Teil aus (z.B. den ersten)
    selected_part = split_place_ids[0]
    ratings = get_place_ratings(API_KEY, selected_part)

    # Ergebnisse anzeigen
    for place_id, rating in ratings.items():
        print(f"place_id: {place_id}, Bewertung: {rating}")

if __name__ == "__main__":
    main()
# Out:
# Anzahl eindeutiger place_ids: 2437
# Teil 1: 610 place_ids
# Teil 2: 609 place_ids
# Teil 3: 609 place_ids
# Teil 4: 609 place_ids
# Fehler beim Abrufen der Daten für ChIJU6MRELlCs0cRaU7ePDewy34: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJ-3GiirtCs0cRl8huquXEd0I: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJL7bZ4z1WskcRJMDlBFMij8U: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJZzA4QN5VskcRgQrbRDJLzSM: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJh-Ay94xWskcR-tVPo0VnC_A: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJmaKuWkAJskcRF0PkFgKrLRA: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJKd3TiloJskcROpQgWcBeuqg: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJi-XbTv0LskcRwKdMPMCF1iE: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJ2TdKmg8JskcRzA8a93wsEdo: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJubaeE7lLskcR-BL_AlTYGJM: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJN4CW3Bj9sUcRSsYbeqBkyV4: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJVUdI_ZGcY0ERebZ8yTgJiYU: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChIJp8gfR1qDtEcRaQqQNlhoEOM: name 'requests' is not defined
# Fehler beim Abrufen der Daten für ChI
# place_id: ChIJ0SIpJP0Gl0cRCfwWXlY41dE, Bewertung: None
# place_id: ChIJuxKUebUFl0cRxMmLEtgbnHI, Bewertung: None
# place_id: ChIJoRPmHmq-l0cRRpNLt4LPE0A, Bewertung: None
# place_id: ChIJGdKpo1Uhl0cRQ7FVUmMBvOU, Bewertung: None
# place_id: ChIJYZg5XO7Al0cR8W-P3eUFmOQ, Bewertung: None
# place_id: ChIJDwdb5zvBl0cR0xMNVb4LsbA, Bewertung: None
# place_id: ChIJUSAqUCzBl0cRg0l7F4QdyXw, Bewertung: None
# place_id: ChIJYWfZ8DLBl0cRFgvLwEY2Ews, Bewertung: None
# place_id: ChIJqxkOe_DPl0cR0QKz86eq89w, Bewertung: None
# place_id: ChIJ--nmVpwDmEcRYHHkqT5s64Y, Bewertung: None
# place_id: ChIJAdDkXNXxl0cRw9fmjG2ysfY, Bewertung: None
# place_id: ChIJvXQq0t3al0cRorcIaZzFNEg, Bewertung: None
# place_id: ChIJSV206PNxl0cRwdEgPzcgFkk, Bewertung: None
# place_id: ChIJ82AD_idpl0cRRmYEolvbd9A, Bewertung: None
# place_id: ChIJ8yoCEEkVl0cR0lw7BtS_rHY, Bewertung: None
# place_id: ChIJ_TO1kI55l0cRbvJSffE3MKQ, Bewertung: None
# place_id: ChIJ5V1ddT40l0cR7ulWLpj0mNQ, Bewertung: None
# place_id: ChIJ_0ELcVgbkUcR2-NX3I8onVo, Bewertung: None
# place_id: ChIJTayyMHobkUcRyDWuTQKfo6A, Bewertung: None
# place_id: ChIJnSodExgPkUcRA_v0ZaCqFnY, Bewertung: None
# place_id: ChIJBVvAi1vykEcRi3eNBQ4vQ8g, Bewertung: None
# place_id: ChIJx72c_W2nkUcREu46umArH4w, Bewertung: None
# place_id: ChIJ0RVTCZjekEcR4fNiOvBGuiw, Bewertung: None
# place_id: ChIJr07ZpcYfkUcREJs5DebWnGY, Bewertung: None
# place_id: ChIJh9pZ22XUlkcRsjZyF-v56jg, Bewertung: None
# place_id: ChIJR1cz2tPOlkcR-GW4SHdXAOc, Bewertung: None
# place_id: ChIJgRakR53TlkcRaz6MuCjMaaw, Bewertung: None
# place_id: ChIJ_4bfAKGxkEcRvv7tQSt61WM, Bewertung: None
# place_id: ChIJMeWU--GZkEcR_iRXAxCuSSc, Bewertung: None
# place_id: ChIJk8Md2sSXkEcR4mvbIYjzCE4, Bewertung: None
# place_id: ChIJLegt0vhzmkcRE4EIxYy69L4, Bewertung: None
# place_id: ChIJlQ_oXFl6CEERmUMoq1gOPHk, Bewertung: None
# place_id: ChIJsyZ299xhmkcRoc3WaUXDsnc, Bewertung: None
# place_id: ChIJx7kaCGdmmkcRffeuob44Vnw, Bewertung: None
# place_id: ChIJv8M0gEWxkUcR1ci-a0KbCq4, Bewertung: None
# place_id: ChIJRRura-hRkEcRsaCvh2St1ok, Bewertung: None
# place_id: ChIJ4RtszEdJkEcRJTrokcQ-KFs, Bewertung: None
# place_id: ChIJSf7umLZCkEcRD4BLlkWJEgY, Bewertung: None
# place_id: ChIJw5Zs-EbymUcRjzfBZo0ilqw, Bewertung: None
# place_id: ChIJ_xtMuwySmUcRlGjNZ7e64mQ, Bewertung: None
# place_id: ChIJGUw1OM_kmUcRPAMdjRBsK_8, Bewertung: None
# place_id: ChIJpWqD_xcHmkcRVsD_WAvBekg, Bewertung: None
# place_id: ChIJZTPBUKMamkcRn-3DVYYMcwg, Bewertung: None
# place_id: ChIJZfpk6ohmmUcRXMwZ0A4CnxA, Bewertung: None
# place_id: ChIJE1lekd9nmUcRbEu-etqy7Ns, Bewertung: None
# place_id: ChIJpTas1-NpmUcRoO2OSboWh5Y, Bewertung: None
# place_id: ChIJQWG7cJTFm0cRsgK1fyBOoVc, Bewertung: None
# place_id: ChIJh5-Yp5EAm0cReNyxtkC-Rrs, Bewertung: None
# place_id: ChIJM5HheowHm0cRkfNQiBWT8jE, Bewertung: None
# place_id: ChIJxf9HN6C5m0cRBHGUEZKCr3A, Bewertung: None
# place_id: ChIJv3FGegOvm0cRipNb4aamN7Q, Bewertung: None
# place_id: ChIJe8Pz_4Kfm0cRgPjvfnenEo0, Bewertung: None
# place_id: ChIJjanWx48-mkcRFyLQR1OEUj8, Bewertung: None
# place_id: ChIJg9OYFtf9nkcRFea13D4I3Vs, Bewertung: None
# place_id: ChIJeYGgNg11nkcRaUcX9ItPZ9w, Bewertung: None
# place_id: ChIJ1R00kNnfnUcRMuOuOf7MXMA, Bewertung: None
# place_id: ChIJdzczUrl1nkcRKl3QOsgrsn4, Bewertung: None
# place_id: ChIJHTir4yHZnUcRpCHn_dZD_aE, Bewertung: None
# place_id: ChIJvfDnJAfYnUcRQXBsqoAVRHI, Bewertung: None
# place_id: ChIJS3RXBybfnUcRqXggMgD5kPk, Bewertung: None
# place_id: ChIJz8ndkEzfnUcRqsgptVhu6xs, Bewertung: None
# place_id: ChIJeT3MsaR1nkcRe0Br6ZsIzlk, Bewertung: None
# place_id: ChIJdZdbjevenUcRpzrqWHvISHI, Bewertung: None
# place_id: ChIJxXBPF07YnUcRu71wHetWKL4, Bewertung: None
# place_id: ChIJP0peCIJ1nkcR_mjIc7T636M, Bewertung: None
# place_id: ChIJSd0O5z52nkcRHcdwVHSEM-Y, Bewertung: None
# place_id: ChIJsaipchJ1nkcRIa_HXbtFeSA, Bewertung: None
# place_id: ChIJx46Og1vfnUcRr8icpwes7Ww, Bewertung: None
# place_id: ChIJaRyLIfIBCUERD7XrNp_vq78, Bewertung: None
# place_id: ChIJxYuvaSzfnUcRRLI5axpi8Mw, Bewertung: None
# place_id: ChIJXY4rf0YadkcRiC9KDRYBpx0, Bewertung: None
# place_id: ChIJE3oNsrIbdkcRrEF3Neyye7E, Bewertung: None
# place_id: ChIJp03PhQfOdUcRYnTMwVvjr6E, Bewertung: None
# place_id: ChIJY-DXARjrdkcRPELOeOuIbkg, Bewertung: None
# place_id: ChIJCQAVmkDsdkcRQKb06Qy9-dA, Bewertung: None
# place_id: ChIJ0QZYpbaVnUcR58u-2bED05c, Bewertung: None
# place_id: ChIJqc4N-6V7nkcRebnUUYQqNWw, Bewertung: None
# place_id: ChIJP4USlBL-nUcR44W-5j5rak8, Bewertung: None
# place_id: ChIJtaRkVy32dUcRvb0N0bFwbw4, Bewertung: None
# place_id: ChIJuwwQ6g0YnkcRIY_d6ZcKgOo, Bewertung: None
# place_id: ChIJ8ZY4F-R_nkcRqgHdrIuaRao, Bewertung: None
# place_id: ChIJH5UTw_UGnUcRyubLWdfZeAw, Bewertung: None
# place_id: ChIJ05g_OYQznEcRZ0lRacrR19Y, Bewertung: None
# place_id: ChIJY4ULa12LnUcRvDsNRBddnKY, Bewertung: None
# place_id: ChIJB3TtMoXXnUcR45aB9cZnVhQ, Bewertung: None
# place_id: ChIJzymjfg3knkcR2tBCTqrpCRs, Bewertung: None
# place_id: ChIJkenam9wUdkcR4suaW84HiGY, Bewertung: None
# place_id: ChIJr3JTbMRsdkcRhHJ9QUnzGdQ, Bewertung: None
# place_id: ChIJ34ifE_d5CEERurJRBSA_fOc, Bewertung: None
# place_id: ChIJUxI_dH4TdkcR046TtWw8iVE, Bewertung: None
# place_id: ChIJQ3Jr7IYHdkcR2oacMvl8_Jg, Bewertung: None
# place_id: ChIJGbFrgiXRnUcRgNep6JC_5zU, Bewertung: None
# place_id: ChIJ4-Sd9tLRnUcRSqKjn6sPO2A, Bewertung: None
# place_id: ChIJTwPKEKRzdkcRwdIqXWaC4pU, Bewertung: None
# place_id: ChIJiT4XM2u1nUcRShBHY9f-Npc, Bewertung: None
# place_id: ChIJF1It63wmnkcRb9obZy-FfZA, Bewertung: None
# place_id: ChIJ4wtJgaNldUcR03QzHvrUnz0, Bewertung: None
# place_id: ChIJP5-_fHERdUcRPntG1emJ5uE, Bewertung: None
# place_id: ChIJOcD0_NHmdEcRCD5gAIQBBcU, Bewertung: None
# place_id: ChIJIc_HWrazn0cRAlt4d6Cl1KU, Bewertung: None
# place_id: ChIJqXX4RyxEdEcRbU8IOEkQbTw, Bewertung: None
# place_id: ChIJ1QlTFtZIdEcRKX6-wixf0Ho, Bewertung: None
# place_id: ChIJ8Tq2wOG7dUcRwB07xE2rw_0, Bewertung: None
# place_id: ChIJT7GTYitpdUcRZtTGbS5WNxk, Bewertung: None
# place_id: ChIJYf8oMmN1dUcRhcZRotGN380, Bewertung: None
# place_id: ChIJ6ca22vfAn0cRLZ33prZnyuY, Bewertung: None
# place_id: ChIJddWTbGnGoUcRLdknOl6d7ag, Bewertung: None
# place_id: ChIJt_AEwtBOdUcRai3IDrc5nAc, Bewertung: None
# place_id: ChIJpWbPBYpvn0cRBPonYNGH0tM, Bewertung: None
# place_id: ChIJSVhQPEven0cR7oM9MZG-muA, Bewertung: None
# place_id: ChIJb_hJuRcboEcR2gG-G3wXnpY, Bewertung: None
# place_id: ChIJ5Wv8W1ayoUcRxYPFEmB1wTA, Bewertung: None
# place_id: ChIJm6QdIJWioUcR6GHFZiSJAPA, Bewertung: None
# place_id: ChIJRYhOCgzOo0cR0zetAAOv4vE, Bewertung: None
# place_id: ChIJxwXurmwWokcRfUFPpznIPIw, Bewertung: None
# place_id: ChIJF4LqLJG3o0cRnqeKTGBNd54, Bewertung: None
# place_id: ChIJH6DRrpZroUcRuUGfwRQJrro, Bewertung: None
# place_id: ChIJ14lHe457oUcRpQLqoi5fvzo, Bewertung: None
# place_id: ChIJqdqxf8oKoUcRlS8GND9WJ_g, Bewertung: None
# place_id: ChIJ25LCPlZUoEcRk43Yydo8HEk, Bewertung: None
# place_id: ChIJ7eI4mJ27mEcR7P3eATVZsBY, Bewertung: None
# place_id: ChIJlxvAmOH4oUcRpvnah5J2TRE, Bewertung: None
# place_id: ChIJ3Zf3xP1Xn0cR7iIAmcAXRUI, Bewertung: None
# place_id: ChIJgbBkFQvfoUcRzV_ub7TiC4E, Bewertung: None
# place_id: ChIJcV7qOa9Xn0cRM7mo6j4JwYM, Bewertung: None
# place_id: ChIJq63PVQdYn0cRcvWPRjLZoZg, Bewertung: None
# place_id: ChIJlfPNQe5Xn0cRquwD6xOjO7w, Bewertung: None
# place_id: ChIJ4SwS4xHrmEcRGQLoO_ZyhcU, Bewertung: None
# place_id: ChIJTwGfupMaokcR1kpYFOPf85M, Bewertung: None
# place_id: ChIJXwQ1Sbldn0cR-LNrr3xJ_R4, Bewertung: None
# place_id: ChIJn58c59kLokcRV8BUydpzXcs, Bewertung: None
# place_id: ChIJi3AgL6o0n0cRqAZZWU5QhKk, Bewertung: None
# place_id: ChIJuarHccFAc0ERs8lojVupxXI, Bewertung: None
# place_id: ChIJlfZjppX3okcRfr11AqL_AXo, Bewertung: None
# place_id: ChIJtcIo4tiPokcR7tcGRDPFlbY, Bewertung: None
# place_id: ChIJq-d5mDGQokcRkrfTQ9raVLI, Bewertung: None
# place_id: ChIJvYJ9J4o7vUcRV--TkYSiOaE, Bewertung: None
# place_id: ChIJOwv8dzzjokcR3eoPYyvftY0, Bewertung: None
# place_id: ChIJRyG5-WYCo0cRDsZhdvjHxwY, Bewertung: None
# place_id: ChIJFQCXIoZPokcRtPigEvBwBXg, Bewertung: None
# place_id: ChIJb5tDofdUvUcRI83xj_jv7qg, Bewertung: None
# place_id: ChIJ0bpvLZpdokcROg_1fZY2r6U, Bewertung: None
# place_id: ChIJj3WJ0ufzokcRdeKgTXT4h-g, Bewertung: None
# place_id: ChIJwW4MK0y9nkcR3xbvQcSxzhA, Bewertung: None
# place_id: ChIJHXoXVFi9nkcRtruofcg9-3I, Bewertung: None
# place_id: ChIJ-2LtYdu8nkcR-NQb839jhNc, Bewertung: None
# place_id: ChIJM4chKON4nEcRp2J1Xxv2vk0, Bewertung: None
# place_id: ChIJkS221oeSnkcRLQS5whN3NmU, Bewertung: None
# place_id: ChIJ68VhHU6jnkcRpVhSad4q0Lw, Bewertung: None
# place_id: ChIJvQw1P3ZOmUcRj7OGQ3HY5xo, Bewertung: None
# place_id: ChIJdU5-ajz-m0cRaz5QcuUv_44, Bewertung: None
# place_id: ChIJhVy6dnkOm0cRJz0q0XCre38, Bewertung: None
# place_id: ChIJ-7U6-4hzm0cRfuhCpq30cvA, Bewertung: None
# place_id: ChIJBVgn4Aj2nEcRiaEp64ZO9jI, Bewertung: None
# place_id: ChIJ_cI4b-6KnEcRCatB-EKaPIg, Bewertung: None
# place_id: ChIJ6eXVxzH1m0cREWDpJZualik, Bewertung: None
# place_id: ChIJa0byWPsomUcRqeLlNOPfy1g, Bewertung: None
# place_id: ChIJQwGkB5mbnEcRdnZpmQqA15g, Bewertung: None
# place_id: ChIJe_byE2ixlUcRzVG3V9eEQJQ, Bewertung: None
# place_id: ChIJEZTvSx60lUcRB7jcg7ziCJc, Bewertung: None
# place_id: ChIJrQmylH4MlUcROa5GfvPc4zE, Bewertung: None
# place_id: ChIJMTDL2PTGlUcRTE-xHC3CV-s, Bewertung: None
# place_id: ChIJJb2v8GaolUcRnETDEX3F1B0, Bewertung: None
# place_id: ChIJebJtKI_alUcRgJ35BvmCC8o, Bewertung: None
# place_id: ChIJfQExjOZRqEcRRze7sZ8pKOw, Bewertung: None
# place_id: ChIJ9dw3SJVRqEcRZp4sOB0XfEE, Bewertung: None
# place_id: ChIJ8V7IXixSqEcRFw0m8wBTrhY, Bewertung: None
# place_id: ChIJ4RuHlBlQqEcRxREfxghw2jU, Bewertung: None
# place_id: ChIJ6U9L0c1PqEcRi-fYqlc1qSs, Bewertung: None
# place_id: ChIJaxslSW5SqEcR57i-mlYKOqA, Bewertung: None
# place_id: ChIJ-YiNLupNqEcRNVlD90AkNBU, Bewertung: None
# place_id: ChIJXaIYexBXqEcRj0oGVzuZNlM, Bewertung: None
# place_id: ChIJM_efePVQqEcR2dhRYOndCB0, Bewertung: None
# place_id: ChIJGwErq8BQqEcR5TCCrsKvvQE, Bewertung: None
# place_id: ChIJw9Jry45QqEcRiI8L4MJLJEQ, Bewertung: None
# place_id: ChIJz8vQxLD4qEcR0ojgU6LyWFI, Bewertung: None
# place_id: ChIJBQRDnGxWqEcRD0bjmGMdOl4, Bewertung: None
# place_id: ChIJR88EWnZZqEcRU8sTobMw8EE, Bewertung: None
# place_id: ChIJm7aI9HZZqEcRu7c_TtU4EQs, Bewertung: None
# place_id: ChIJqckEHOZaqEcRTc2aQj50Pxc, Bewertung: None
# place_id: ChIJyR22UtFaqEcRZhFt-nQ9ysE, Bewertung: None
# place_id: ChIJsdXX_FNQqEcR-oevGPODpOk, Bewertung: None
# place_id: ChIJE0rEqflbqEcR2INC-5nnIQQ, Bewertung: None
# place_id: ChIJkxA_2ptPqEcRZZ6FK7z5YuE, Bewertung: None
# place_id: ChIJlWDzvpdHqEcR96QcpmawjRk, Bewertung: None
# place_id: ChIJay4MKV5QqEcRKaqKcVGCh80, Bewertung: None
# place_id: ChIJMzUBkGVJqEcRCL9z6OV6XLo, Bewertung: None
# place_id: ChIJg3gnJ55JqEcRu0dAJH3sWyY, Bewertung: None
# place_id: ChIJGT9tm5VOqEcR3wa3iSNTf9E, Bewertung: None
# place_id: ChIJ9ddOxvdTqEcRFr2wHhLY_sU, Bewertung: None
# place_id: ChIJ-WkHU_rAqEcR8dT9dZ5gBwA, Bewertung: None
# place_id: ChIJ76sVrXl0CEcRCQAvCQBF9jI, Bewertung: None
# place_id: ChIJL-bWM_f1qEcReN6gU5his3I, Bewertung: None
# place_id: ChIJxfaOBTtfqEcRialRsvQLTYI, Bewertung: None
# place_id: ChIJy49ZtPD1qEcRhIKjRRxnqNE, Bewertung: None
# place_id: ChIJe2LJsumzqUcRCR28J4cpaHo, Bewertung: None
# place_id: ChIJ0w3b_rQ_qEcRWwMvl2GEIuc, Bewertung: None
# place_id: ChIJVVVVCob-p0cRp7SfjZwXHhE, Bewertung: None
# place_id: ChIJX-IgQPj1p0cRQD1XV7wRl4w, Bewertung: None
# place_id: ChIJq5D8cobRqEcRIAV5tbWEGLQ, Bewertung: None
# place_id: ChIJ4bMA7kF4B0cRus-bBANkaDM, Bewertung: None
# place_id: ChIJG7qm1QDaqUcRpiCpN7npG2w, Bewertung: None
# place_id: ChIJh60cQyAAqUcR7RNvE31ZTS0, Bewertung: None
# place_id: ChIJ5frbkrYjCEcRZ1ZrAy9KvYM, Bewertung: None
# place_id: ChIJDzefwUXtB0cRMmpll2X4MGk, Bewertung: None
# place_id: ChIJGfxJX1gxqEcRckaDECCNl-4, Bewertung: None
# place_id: ChIJD9ym6bCSZEERLxXzX2Wy8A4, Bewertung: None
# place_id: ChIJf0TBAY1IZUERva6P0i44ncI, Bewertung: None
# place_id: ChIJ54jDygrzqEcRKsXe9PMF3ak, Bewertung: None
# place_id: ChIJl3zXMCV_CEcRWkBW4cJU-ac, Bewertung: None
# place_id: ChIJ37y-eop4qEcRuSOtSVZ4JYU, Bewertung: None
# place_id: ChIJk0hYnEuTqUcRhn5gYO0vvRw, Bewertung: None
# place_id: ChIJ0b1F7EX7qUcR5wfd1skoHDM, Bewertung: None
# place_id: ChIJoTu35-ZZrEcRbLzQdWTnVjU, Bewertung: None
# place_id: ChIJc-zIa0xXrEcRXVRNH4yzCGg, Bewertung: None
# place_id: ChIJN3-fdGCFq0cRfni_srCEuXg, Bewertung: None
# place_id: ChIJZaVZyJnDq0cR_Lk_F9Cxj1g, Bewertung: None
# place_id: ChIJ9c6HBPb4q0cRWo5bjmNfn34, Bewertung: None
# place_id: ChIJy8cPxH0_rEcRQ7eVJxLRSmQ, Bewertung: None
# place_id: ChIJ1TAXEi5iq0cRciMs0ipajcQ, Bewertung: None
# place_id: ChIJU5WQnGBiq0cRdKeykMuiWVE, Bewertung: None
# place_id: ChIJJzo-TVjHrUcRswybCjK0bIU, Bewertung: None
# place_id: ChIJf4fi65w9YkERIkfHgvjKfUg, Bewertung: None
# place_id: ChIJH2YLhMIGq0cRFCmCY3xN_Vs, Bewertung: None
# place_id: ChIJr_Jbz61zrkcRw-jZFEMT2uQ, Bewertung: None
# place_id: ChIJnd0H-7WcrkcRfmRQmzO91KI, Bewertung: None
# place_id: ChIJISC21w44p0cRQF7htEo7dl8, Bewertung: None
# place_id: ChIJ4z0eBkXRoEcRnUZuslbRbak, Bewertung: None
# place_id: ChIJYUdBFatRp0cRa-MLSwGLSlY, Bewertung: None
# place_id: ChIJ48IAYMDeCUcRyauwMGEFvFc, Bewertung: None
# place_id: ChIJmXGyxiLnoEcRa5wst5j74uQ, Bewertung: None
# place_id: ChIJrw5jpX3QoEcRttPuN7rPEHQ, Bewertung: None
# place_id: ChIJawLDTAfNoEcR9z6T8LYdQ7Y, Bewertung: None
# place_id: ChIJNaNm6D3NoEcRkRvzKmkrtnE, Bewertung: None
# place_id: ChIJK_qhM1LPCUcRSVHUP6W9_jQ, Bewertung: None
# place_id: ChIJ7fcDjkzOCUcRfjRZesIG3ao, Bewertung: None
# place_id: ChIJbUztDKpDCEcRropJ3I1FKxk, Bewertung: None
# place_id: ChIJhR22XtVKCEcR_G4gF5b4Y94, Bewertung: None
# place_id: ChIJRVnt7nTeCEcRnM6xiR-g5eA, Bewertung: None
# place_id: ChIJHxzhpaDiCEcRgR4Mnh4pUrg, Bewertung: None
# place_id: ChIJQ87mIIaLCEcRz43P--gLglA, Bewertung: None
# place_id: ChIJiZAiP8DVCUcRRjak8stNoqg, Bewertung: None
# place_id: ChIJ2wcQ8dqCp0cRPGBe7767P5c, Bewertung: None
# place_id: ChIJV0xSKDXBCUcR-Qa_boYFNiM, Bewertung: None
# place_id: ChIJj0nSC7H3pkcRUoBmkJdyQoA, Bewertung: None
# place_id: ChIJXXjPjh33pkcRXKHgskaxUF8, Bewertung: None
# place_id: ChIJw1jiKnnipkcRPC4uLeMTRCU, Bewertung: None
# place_id: ChIJSYH9q9n1pkcR0Rq_XDz28tU, Bewertung: None
# place_id: ChIJEZr1_VhbpkcRpENSgm78D5A, Bewertung: None
# place_id: ChIJYSNjoW9fpkcRgiGqMuN454o, Bewertung: None
# place_id: ChIJDy5_HV4RpkcRdcdjz8cIEhg, Bewertung: None
# place_id: ChIJkVvKhxdjpkcRZBzDi2fCZWs, Bewertung: None
# place_id: ChIJETge_ktjpkcRzG2UDFoi5QY, Bewertung: None
# place_id: ChIJhyPaU3lfr0cRb16KZaqTwXA, Bewertung: None
# place_id: ChIJkdlSZn72pUcRf-CwzhKlBaA, Bewertung: None
# place_id: ChIJEYJcxWA7r0cRtviyFxVkbOY, Bewertung: None
# place_id: ChIJvTW80usNpkcRIBKaKMcUK4U, Bewertung: None
# place_id: ChIJU24VHzmEpUcRbMLoymBmegE, Bewertung: None
# place_id: ChIJ_4YtquygpUcR_pgT0VHzMqc, Bewertung: None
# place_id: ChIJrUPihIKkpUcRTss-PGK8O98, Bewertung: None
# place_id: ChIJNQB_Z0b4pUcRcHnWWCgDz7A, Bewertung: None
# place_id: ChIJJ5TbY7DFpUcRj-bIaS2Wt-g, Bewertung: None
# place_id: ChIJyV_h3hLBpUcROACvZ-VXgiY, Bewertung: None
# place_id: ChIJeXktuZb1pUcRZHRxOFEOlB0, Bewertung: None
# place_id: ChIJZ4xFLEXhrkcR0Pg8G5qI1-s, Bewertung: None
# place_id: ChIJKQssNnXPp0cRNjWtPNMArvE, Bewertung: None
# place_id: ChIJbyNVEIFypEcRM0kxjn9OIbY, Bewertung: None
# place_id: ChIJFQ3BaTbPpkcRqUogxTQtBvU, Bewertung: None
# place_id: ChIJ27eEuACao0cRtyySTHABijc, Bewertung: None
# place_id: ChIJA9GZA_zEpEcRiWuSdge5Lmk, Bewertung: None
# place_id: ChIJsTo2KoeqpUcRtndwLVLRjFY, Bewertung: None
# place_id: ChIJW3yBCQhno0cR6a0wJRrprdM, Bewertung: None
# place_id: ChIJ2QJUj5CbpEcRsgi9hA9Mq3A, Bewertung: None
# place_id: ChIJz4YIslmNpEcRIHiCOX0R498, Bewertung: None
# place_id: ChIJEassD89IpEcRvn86QJjucQE, Bewertung: None
# place_id: ChIJr8dBkRF1o0cR5W3NMZZ0wZI, Bewertung: None
# place_id: ChIJ4QNXbrx-pEcRDAUCEGPlPYQ, Bewertung: None
# place_id: ChIJ2T6jXf67o0cR3tMbGYZ9d8g, Bewertung: None
# place_id: ChIJw4liHkCNo0cRL6j9JMKZlKE, Bewertung: None
# place_id: ChIJjTFmFeMFpEcRjggFxPprbRQ, Bewertung: None
# place_id: ChIJR3FNOHfZo0cRlHCCuIgNr4w, Bewertung: None
# place_id: ChIJzz3lLdZboUcRqGNTn_5TF2Y, Bewertung: None
# place_id: ChIJYRPJL76xpkcRoCwQ-q-erfU, Bewertung: None
# place_id: ChIJLQVfHp0roUcRjve2R9mqwY8, Bewertung: None
# place_id: ChIJ9yvAKoIgp0cRQCruo2WSxyU, Bewertung: None

# %%
# !pip install googlemaps
# !pip install pandas
# !pip install openpyxl

import googlemaps
import pandas as pd
import time
from typing import Dict, List, Any

# Google Maps Client initialisieren
gmaps = googlemaps.Client(key='AIzaSyA34t4OLue4SRaxHQ0SNhoJ-Sfvuvnnblo')  # Ersetzen Sie 'API_KEY' mit Ihrem tatsächlichen Schlüssel

# 1. CSV-Datei einlesen
df_reviews = pd.read_csv('/content/08_data_and_covariates.csv')

# 2. Eindeutige place_ids extrahieren
unique_place_ids = df_reviews['place_id'].unique().tolist()
print(f"Anzahl eindeutiger place_ids: {len(unique_place_ids)}")

# 3. Liste in 4 Teile splitten
def split_list(lst: List[Any], parts: int = 4) -> List[List[Any]]:
    return [lst[i::parts] for i in range(parts)]

split_place_ids = split_list(unique_place_ids, parts=4)

# 4. Bewertungen abrufen und speichern
def get_place_details(place_ids: List[str]) -> Dict[str, Dict[str, Any]]:
    place_details = {}

    for place_id in place_ids:
        try:
            place = gmaps.place(place_id=place_id, language='de')

            if place['status'] == 'OK':
                result = place['result']
                place_details[place_id] = {
                    'average_rating': result.get('rating'),
                    'total_ratings': result.get('user_ratings_total'),
                    'name': result.get('name'),
                    'address': result.get('formatted_address')
                }
            else:
                print(f"Fehler für place_id {place_id}: {place['status']}")
                place_details[place_id] = None

            # Rate limiting
            time.sleep(1)  # 1 Anfrage pro Sekunde

        except Exception as e:
            print(f"Fehler beim Abrufen der Daten für {place_id}: {str(e)}")
            place_details[place_id] = None

    return place_details

# 5. Daten für einen Teil abrufen (hier Teil 1, anpassbar)
place_details = get_place_details(split_place_ids[0])

# 6. Durchschnittliche Bewertungen mit Originaldaten verknüpfen
def merge_ratings_with_reviews(df_reviews: pd.DataFrame, place_details: Dict) -> pd.DataFrame:
    # DataFrame aus den Place Details erstellen
    df_place_details = pd.DataFrame.from_dict(place_details, orient='index')
    df_place_details.reset_index(inplace=True)
    df_place_details.rename(columns={'index': 'place_id'}, inplace=True)

    # Originaldaten mit den durchschnittlichen Bewertungen mergen
    df_merged = pd.merge(
        df_reviews,
        df_place_details[['place_id', 'average_rating', 'total_ratings', 'name', 'address']],
        on='place_id',
        how='left'
    )

    return df_merged

# 7. Daten zusammenführen
df_final = merge_ratings_with_reviews(df_reviews, place_details)

# 8. Ergebnisse speichern
output_file = '09_data_covariates_avg.csv'
df_final.to_csv(output_file, index=False, encoding='utf-8-sig')
print(f"Ergebnisse wurden in {output_file} gespeichert")

# Optional: Ergebnisse anzeigen
print("\nBeispielhafte Ergebnisse:")
print(df_final[['ort', 'name', 'bewertung', 'average_rating', 'total_ratings']].head())
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     339             else:
# --> 340                 result = self._get_body(response)
#     341             self.sent_times.append(time.time())
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _get_body(self, response)
#     365         if api_status == "OVER_QUERY_LIMIT":
# --> 366             raise googlemaps.exceptions._OverQueryLimit(
#     367                 api_status, body.get("error_message"))
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your rate-limit for this API.)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-fbb3a01f26db> in <cell line: 0>()
#       1 # 5. Daten für einen Teil abrufen (hier Teil 1, anpassbar)
# ----> 2 place_details = get_place_details(split_place_ids[0])
#
# <ipython-input-8-f40a1afbcf0e> in get_place_details(place_ids)
#       5     for place_id in place_ids:
#       6         try:
# ----> 7             place = gmaps.place(place_id=place_id, language='de')
#       8
#       9             if place['status'] == 'OK':
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     443     def wrapper(*args, **kwargs):
#     444         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445         result = func(*args, **kwargs)
#     446         try:
#     447             del args[0]._extra_params
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/places.py in place(client, place_id, session_token, fields, language, reviews_no_translations, reviews_sort)
#     494         params["reviews_sort"] = reviews_sort
#     495
# --> 496     return client._request("/maps/api/place/details/json", params)
#     497
#     498
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     346
#     347             # Retry request.
# --> 348             return self._request(url, params, first_request_time,
#     349                                  retry_counter + 1, base_url, accepts_clientid,
#     350                                  extract_body, requests_kwargs, post_json)
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     297
#     298             # Jitter this value by 50% and pause.
# --> 299             time.sleep(delay_seconds * (random.random() + 0.5))
#     300
#     301         authed_url = self._generate_auth_url(url, params, accepts_clientid)
#
# KeyboardInterrupt:

# %% [markdown]
# Mit YT Anleitung

# %%
! pip install -U googlemaps

import googlemaps
import pandas as pd


gmaps = googlemaps.Client(key='INSERT_KEY_HERE')

place = gmaps.place(place_id = place_id)

# 1. CSV-Datei einlesen
df_reviews = pd.read_csv('/content/08_data_and_covariates.csv')

# 2. Eindeutige place_ids extrahieren
unique_place_ids = df_reviews['place_id'].unique().tolist()
print(f"Anzahl eindeutiger place_ids: {len(unique_place_ids)}")

avg_star = [] #empty list which will hold dictionaries of reviews

for i in range(len(place['result']['reviews'])):
    text = place['result']['reviews'][i]['text']
    rating = place['result']['reviews'][i]['rating']

    reviews.append({'rating':rating,
                   'text':text
                   }
                  )

df = pd.DataFrame(reviews)



# if you want to save to csv:
df.to_csv('Mcdonalds_google_reviews.csv', index=False)

# %%
import googlemaps

def get_place_rating(api_key, place_id):
    """
    Ruft die Sternebewertung eines Ortes mithilfe der Google Places API ab.

    Args:
        api_key (str): Ihr Google Maps API-Schlüssel.
        place_id (str): Die Place-ID des Ortes.

    Returns:
        float: Die Sternebewertung des Ortes oder None, falls nicht gefunden.
    """
    gmaps = googlemaps.Client(key=AIzaSyA34t4OLue4SRaxHQ0SNhoJ-Sfvuvnnblo)
    place = gmaps.place(place_id=ChIJU6MRELlCs0cRaU7ePDewy34, fields=['rating'])
    if place and place['result'] and 'rating' in place['result']:
        return place['result']['rating']
    else:
        return None

if rating:
    print(f"Die Sternebewertung für Ort {place_id} ist: {rating}")
else:
    print(f"Die Sternebewertung für Ort {place_id} konnte nicht gefunden werden.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ff96f20a86fe> in <cell line: 0>()
# ----> 1 import googlemaps
#       2
#       3 def get_place_rating(api_key, place_id):
#       4     """
#       5     Ruft die Sternebewertung eines Ortes mithilfe der Google Places API ab.
#
# ModuleNotFoundError: No module named 'googlemaps'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
